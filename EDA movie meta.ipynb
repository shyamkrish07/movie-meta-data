# %% [markdown]
# # EXPLORATORY DATA ANALYSIS
# MOVIE  DATA
#
# # LOAD LIBRARIES
# IMPORTING THE REQUIRED LIBRARY FOR EDA

# %% [markdown]
# HERE IS THE LIBRARIES USED TO PERFORM EDA

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt             
sns.set(color_codes=True)

# %% [markdown]
# # TO LOAD A NECESSARY LIBRARY

# %%
import pandas as pd
df=pd.read_csv(r'D:\DataScience\my data\movie_metadata.csv')
print(df)
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# # LOAD HEAD

# %% [markdown]
# LOADING HEAD OF 5

# %%
df1=df.head(5)

# %%
df1
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# # IDENTIFYING DATATYPES

# %%
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %% [markdown]
# # LOAD INFO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %% [markdown]
# # TO LOAD SOME COLUMNS

# %%
df1=df.columns
df1
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %% [markdown]
# # SELECTION OF SOME PARTICULAR COLUMNS ONLY AND ALSO LOAD HEAD OF 10

# %%
df1=df[['title_year','movie_title','country','director_name']]
df1.head(10)
# Out:
#    title_year                                        movie_title country  \
# 0      2009.0                                            Avatar      USA
# 1      2007.0          Pirates of the Caribbean: At World's End      USA
# 2      2015.0                                           Spectre       UK
# 3      2012.0                             The Dark Knight Rises      USA
# 4         NaN  Star Wars: Episode VII - The Force Awakens    ...     NaN
# 5      2012.0                                       John Carter      USA
# 6      2007.0                                      Spider-Man 3      USA
# 7      2010.0                                           Tangled      USA
# 8      2015.0                           Avengers: Age of Ultron      USA
# 9      2009.0            Harry Potter and the Half-Blood Prince       UK
#
#        director_name
# 0      James Cameron
# 1     Gore Verbinski
# 2         Sam Mendes
# 3  Christopher Nolan
# 4        Doug Walker
# 5     Andrew Stanton
# ...

# %% [markdown]
# # DROPPING IRRELEVANT COLUMNS AND LOAD HEAD OF 10

# %%
df1=df.drop(columns=['title_year','movie_title','country','director_name'])
df1.head(10)
# Out:
#    color  num_critic_for_reviews  duration  director_facebook_likes  \
# 0  Color                   723.0     178.0                      0.0
# 1  Color                   302.0     169.0                    563.0
# 2  Color                   602.0     148.0                      0.0
# 3  Color                   813.0     164.0                  22000.0
# 4    NaN                     NaN       NaN                    131.0
# 5  Color                   462.0     132.0                    475.0
# 6  Color                   392.0     156.0                      0.0
# 7  Color                   324.0     100.0                     15.0
# 8  Color                   635.0     141.0                      0.0
# 9  Color                   375.0     153.0                    282.0
#
#    actor_3_facebook_likes       actor_2_name  actor_1_facebook_likes  \
# 0                   855.0   Joel David Moore                  1000.0
# 1                  1000.0      Orlando Bloom                 40000.0
# ...

# %% [markdown]
# # RENAMING COLUMNS

# %%
df1=df.rename(columns={'director_name':'Director_Name','duration':'Duration','actor_2_name':'Actor2_Name','gross':'Gross','language':'Language'})
df1
# Out:
#       color      Director_Name  num_critic_for_reviews  Duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       Actor2_Name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# # RECOGNIZING NULL VALUES

# %%
df.isnull()
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     False          False                   False     False
# 1     False          False                   False     False
# 2     False          False                   False     False
# 3     False          False                   False     False
# 4      True          False                    True      True
# ...     ...            ...                     ...       ...
# 5038  False          False                   False     False
# 5039  False           True                   False     False
# 5040  False          False                   False     False
# 5041  False          False                   False     False
# 5042  False          False                   False     False
#
#       director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                       False                   False         False
# 1                       False                   False         False
# ...

# %% [markdown]
# # FINDING SOME NULL VALUES

# %%
df.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      14
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %% [markdown]
# # TOTAL NULL VALUE OF ALL COLUMNS

# %%
df.isnull().sum().sum()
# Out:
# 2700

# %% [markdown]
# # REMOVING NULL VALUES USING dropna

# %%
df1=df.dropna(inplace=True)
df1

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# # REMOVING NULL VALUES USING fillna

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# # REMOVING NULL VALUES USING interpolate

# %%
df.interpolate(method='polynomial',order=5,inplace=True)
# Out:
# C:\Users\thasn\AppData\Local\Temp\ipykernel_5944\2519121450.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method='polynomial',order=5,inplace=True)

# %%
df.isnull().sum()
# Out:
# color                        0
# director_name                0
# num_critic_for_reviews       0
# duration                     0
# director_facebook_likes      0
# actor_3_facebook_likes       0
# actor_2_name                 0
# actor_1_facebook_likes       0
# gross                        0
# genres                       0
# actor_1_name                 0
# movie_title                  0
# num_voted_users              0
# cast_total_facebook_likes    0
# actor_3_name                 0
# facenumber_in_poster         0
# plot_keywords                0
# movie_imdb_link              0
# num_user_for_reviews         0
# language                     0
# country                      0
# content_rating               0
# budget                       0
# title_year                   0
# actor_2_facebook_likes       0
# imdb_score                   0
# aspect_ratio                 0
# movie_facebook_likes         0
# dtype: int64

# %% [markdown]
# # RECOGNIZING UNIQUE VALUE

# %%
df.nunique()
# Out:
# color                           2
# director_name                1658
# num_critic_for_reviews        525
# duration                      151
# director_facebook_likes       394
# actor_3_facebook_likes        882
# actor_2_name                 2187
# actor_1_facebook_likes        713
# gross                        3637
# genres                        745
# actor_1_name                 1427
# movie_title                  3654
# num_voted_users              3673
# cast_total_facebook_likes    3243
# actor_3_name                 2586
# facenumber_in_poster           19
# plot_keywords                3655
# movie_imdb_link              3655
# num_user_for_reviews          940
# language                       33
# country                        45
# content_rating                 12
# budget                        359
# title_year                     74
# actor_2_facebook_likes        855
# imdb_score                     74
# aspect_ratio                   18
# ...

# %% [markdown]
# # SUM OF UNIQUE VALUES

# %%
df.nunique().sum()
# Out:
# 35873

# %% [markdown]
# # TO FIND DUPLICATES

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 5       False
#         ...
# 5026    False
# 5027    False
# 5033    False
# 5035    False
# 5042    False
# Length: 3755, dtype: bool

# %% [markdown]
# # TO REMOVE DUPLICATES

# %%
rem_dup=df.drop_duplicates(['duration','imdb_score',])
print(rem_dup)
# Out:
#                  color      director_name  num_critic_for_reviews  duration  \
# 0                Color      James Cameron                   723.0     178.0
# 1                Color     Gore Verbinski                   302.0     169.0
# 2                Color         Sam Mendes                   602.0     148.0
# 3                Color  Christopher Nolan                   813.0     164.0
# 5                Color     Andrew Stanton                   462.0     132.0
# ...                ...                ...                     ...       ...
# 4964             Color          E.L. Katz                   193.0      88.0
# 4973   Black and White   Darren Aronofsky                   138.0      84.0
# 4998             Color       Kevin Jordan                    21.0      90.0
# 5008   Black and White        Kevin Smith                   136.0     102.0
# 5033             Color      Shane Carruth                   143.0      77.0
#
# ...

# %% [markdown]
# # LOAD GROUP BY

# %%
df.groupby
# Out:
# <bound method DataFrame.groupby of       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 5     Color     Andrew Stanton                   462.0     132.0
# ...     ...                ...                     ...       ...
# 5026  Color    Olivier Assayas                    81.0     110.0
# 5027  Color       Jafar Panahi                    64.0      90.0
# 5033  Color      Shane Carruth                   143.0      77.0
# 5035  Color   Robert Rodriguez                    56.0      81.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# ...

# %% [markdown]
# # COUNT TOTAL NUMBER OF ROWS AND COLUMNS

# %%
df.shape
# Out:
# (3755, 28)

# %% [markdown]
# # COUNT NUMBER OF ROWS

# %%
df.count()
# Out:
# color                        3755
# director_name                3755
# num_critic_for_reviews       3755
# duration                     3755
# director_facebook_likes      3755
# actor_3_facebook_likes       3755
# actor_2_name                 3755
# actor_1_facebook_likes       3755
# gross                        3755
# genres                       3755
# actor_1_name                 3755
# movie_title                  3755
# num_voted_users              3755
# cast_total_facebook_likes    3755
# actor_3_name                 3755
# facenumber_in_poster         3755
# plot_keywords                3755
# movie_imdb_link              3755
# num_user_for_reviews         3755
# language                     3755
# country                      3755
# content_rating               3755
# budget                       3755
# title_year                   3755
# actor_2_facebook_likes       3755
# imdb_score                   3755
# aspect_ratio                 3755
# ...

# %% [markdown]
# # TO LOCATE ROW WISE AND COLUM NWISE

# %%
df.iloc[:,[2,4,6,8]]
# Out:
#       num_critic_for_reviews  director_facebook_likes       actor_2_name  \
# 0                      723.0                      0.0   Joel David Moore
# 1                      302.0                    563.0      Orlando Bloom
# 2                      602.0                      0.0       Rory Kinnear
# 3                      813.0                  22000.0     Christian Bale
# 5                      462.0                    475.0    Samantha Morton
# ...                      ...                      ...                ...
# 5026                    81.0                    107.0     Béatrice Dalle
# 5027                    64.0                    397.0  Nargess Mamizadeh
# 5033                   143.0                    291.0     David Sullivan
# 5035                    56.0                      0.0    Peter Marquardt
# 5042                    43.0                     16.0   Brian Herzlinger
#
#             gross
# 0     760505847.0
# 1     309404152.0
# 2     200074175.0
# ...

# %%
df.iloc[-1:,[3,4,5,6]]
# Out:
#       duration  director_facebook_likes  actor_3_facebook_likes  \
# 5042      90.0                     16.0                    16.0
#
#           actor_2_name
# 5042  Brian Herzlinger

# %%
df.iloc[1:6,[1,4,7,9,12]]
# Out:
#        director_name  director_facebook_likes  actor_1_facebook_likes  \
# 1     Gore Verbinski                    563.0                 40000.0
# 2         Sam Mendes                      0.0                 11000.0
# 3  Christopher Nolan                  22000.0                 27000.0
# 5     Andrew Stanton                    475.0                   640.0
# 6          Sam Raimi                      0.0                 24000.0
#
#                       genres  num_voted_users
# 1   Action|Adventure|Fantasy           471220
# 2  Action|Adventure|Thriller           275868
# 3            Action|Thriller          1144337
# 5    Action|Adventure|Sci-Fi           212204
# 6   Action|Adventure|Romance           383056

# %%
df.iloc[2:8,[2,3,5,6,8,9,10]]
# Out:
#    num_critic_for_reviews  duration  actor_3_facebook_likes  \
# 2                   602.0     148.0                   161.0
# 3                   813.0     164.0                 23000.0
# 5                   462.0     132.0                   530.0
# 6                   392.0     156.0                  4000.0
# 7                   324.0     100.0                   284.0
# 8                   635.0     141.0                 19000.0
#
#         actor_2_name        gross  \
# 2       Rory Kinnear  200074175.0
# 3     Christian Bale  448130642.0
# 5    Samantha Morton   73058679.0
# 6       James Franco  336530303.0
# 7       Donna Murphy  200807262.0
# 8  Robert Downey Jr.  458991599.0
#
#                                               genres     actor_1_name
# 2                          Action|Adventure|Thriller  Christoph Waltz
# 3                                    Action|Thriller        Tom Hardy
# 5                            Action|Adventure|Sci-Fi     Daryl Sabara
# ...

# %% [markdown]
# # FILTERING DATAFRAMES
# DATA WHICH IS MOVIE FACEBOOK LIKES GEATER THAN 118000

# %%
df1=df[df["movie_facebook_likes"]>118000]
df1
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 3     Color      Christopher Nolan                   813.0     164.0
# 10    Color            Zack Snyder                   673.0     183.0
# 17    Color            Joss Whedon                   703.0     173.0
# 29    Color        Colin Trevorrow                   644.0     124.0
# 46    Color           Marc Forster                   654.0     123.0
# 96    Color      Christopher Nolan                   712.0     169.0
# 97    Color      Christopher Nolan                   642.0     148.0
# 128   Color          George Miller                   739.0     120.0
# 179   Color  Alejandro G. Iñárritu                   556.0     156.0
# 223   Color                Ang Lee                   552.0     127.0
# 246   Color         Alfonso Cuarón                   738.0      91.0
# 268   Color             Gavin Hood                   326.0     114.0
# 278   Color           Ridley Scott                   568.0     151.0
# ...

# %% [markdown]
# # BUDGET LESSTHAN 200000000

# %%
df1=df[df["budget"]<200000000]
df1
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 24    Color       Chris Weitz                   251.0     113.0
# 29    Color   Colin Trevorrow                   644.0     124.0
# 40    Color   Joseph Kosinski                   469.0     125.0
# 45    Color         James Wan                   424.0     140.0
# 46    Color      Marc Forster                   654.0     123.0
# ...     ...               ...                     ...       ...
# 5026  Color   Olivier Assayas                    81.0     110.0
# 5027  Color      Jafar Panahi                    64.0      90.0
# 5033  Color     Shane Carruth                   143.0      77.0
# 5035  Color  Robert Rodriguez                    56.0      81.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 24                      129.0                  1000.0          Eva Green
# ...

# %% [markdown]
# # BUDGET GREATERTHAN 210000000 AND BUDGET LESSTHAN 230000000

# %%
df1= df.loc[(df["budget"]>210000000) & (df["budget"]<230000000)]
df1
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 13    Color    Gore Verbinski                   313.0     151.0
# 14    Color    Gore Verbinski                   450.0     150.0
# 15    Color       Zack Snyder                   733.0     143.0
# 16    Color    Andrew Adamson                   258.0     150.0
# 17    Color       Joss Whedon                   703.0     173.0
# 19    Color  Barry Sonnenfeld                   451.0     106.0
# 23    Color     Peter Jackson                   509.0     186.0
# 38    Color         Sam Raimi                   525.0     130.0
# 794   Color       Joss Whedon                   703.0     173.0
# 4778  Color         Sam Raimi                   525.0     130.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 13                      563.0                  1000.0         Orlando Bloom
# 14                      563.0                  1000.0           Ruth Wilson
# ...

# %% [markdown]
# # NUMBER OF VOTED USERS GREATERTHAN 50000

# %%
df1=df[df["num_voted_users"]<500000]
df1
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 1     Color    Gore Verbinski                   302.0     169.0
# 2     Color        Sam Mendes                   602.0     148.0
# 5     Color    Andrew Stanton                   462.0     132.0
# 6     Color         Sam Raimi                   392.0     156.0
# 7     Color      Nathan Greno                   324.0     100.0
# ...     ...               ...                     ...       ...
# 5026  Color   Olivier Assayas                    81.0     110.0
# 5027  Color      Jafar Panahi                    64.0      90.0
# 5033  Color     Shane Carruth                   143.0      77.0
# 5035  Color  Robert Rodriguez                    56.0      81.0
# 5042  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 1                       563.0                  1000.0      Orlando Bloom
# ...

# %% [markdown]
# # DATA WHICH COLOR IS COLOR ,COUNTRY IS USA AND TITLE YEAR LESSTHAN 2005

# %%
df.loc[(df['color']=='color')&(df['country']=='USA')&(df['title_year']<2005)]
# Out:
# Empty DataFrame
# Columns: [color, director_name, num_critic_for_reviews, duration, director_facebook_likes, actor_3_facebook_likes, actor_2_name, actor_1_facebook_likes, gross, genres, actor_1_name, movie_title, num_voted_users, cast_total_facebook_likes, actor_3_name, facenumber_in_poster, plot_keywords, movie_imdb_link, num_user_for_reviews, language, country, content_rating, budget, title_year, actor_2_facebook_likes, imdb_score, aspect_ratio, movie_facebook_likes]
# Index: []
#
# [0 rows x 28 columns]

# %% [markdown]
# # TO SORT

# %%
df1=df.sort_values(by=['language','title_year','imdb_score'])
df1
# Out:
#       color        director_name  num_critic_for_reviews  duration  \
# 3504  Color        Phillip Noyce                    74.0      94.0
# 377   Color       Sydney Pollack                   227.0     128.0
# 4393  Color        Nadine Labaki                   109.0      95.0
# 1866  Color           Mel Gibson                   406.0     120.0
# 2890  Color  Angelina Jolie Pitt                   110.0     127.0
# ...     ...                  ...                     ...       ...
# 3311  Color  Chatrichalerm Yukol                    31.0     300.0
# 3659  Color      Prachya Pinkaew                   112.0     111.0
# 2740  Color             Tony Jaa                   110.0     110.0
# 4463  Color             Ham Tran                    15.0     135.0
# 4101  Color           Gavin Hood                   152.0      94.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 3504                    176.0                    46.0        David Gulpilil
# ...

# %% [markdown]
# # SORT IN DESCENDING ORDER

# %%
df1=df.sort_values(by=['director_name'],ascending=False)
df1
# Out:
#       color       director_name  num_critic_for_reviews  duration  \
# 3678  Color    Émile Gaudreault                    67.0      92.0
# 3242  Color  Álex de la Iglesia                    71.0     104.0
# 3569  Color      Zal Batmanglij                   200.0     116.0
# 4452  Color            Zak Penn                    60.0      94.0
# 709   Color         Zack Snyder                   460.0     117.0
# ...     ...                 ...                     ...       ...
# 4070  Color         Adam Marcus                   112.0      91.0
# 4399  Color       Adam Goldberg                    22.0     111.0
# 2909  Color        Abel Ferrara                    48.0      99.0
# 2182  Color       Aaron Seltzer                    99.0      85.0
# 3497  Color     Aaron Schneider                   160.0     100.0
#
#       director_facebook_likes  actor_3_facebook_likes        actor_2_name  \
# 3678                      9.0                    71.0          Luke Kirby
# ...

# %%
df1=df.describe()

# %%
df1
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             3755.000000  3755.000000              3755.000000
# mean               167.392277   110.260186               807.463648
# std                123.465521    22.649332              3068.570417
# min                  2.000000    37.000000                 0.000000
# 25%                 77.000000    96.000000                11.000000
# 50%                139.000000   106.000000                64.000000
# 75%                224.000000   120.000000               235.000000
# max                813.000000   330.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             3755.000000             3755.000000  3.755000e+03
# mean               771.484953             7753.390146  5.262614e+07
# std               1894.460316            15520.897163  7.032249e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# # TO LOAD MEAN

# %%
df1.mean()
# Out:
# num_critic_for_reviews       6.626072e+02
# duration                     5.721137e+02
# director_facebook_likes      3.867629e+03
# actor_3_facebook_likes       3.842806e+03
# actor_1_facebook_likes       8.522179e+04
# gross                        1.235944e+08
# num_voted_users              2.692199e+05
# cast_total_facebook_likes    8.917031e+04
# facenumber_in_poster         4.755524e+02
# num_user_for_reviews         1.285709e+03
# budget                       1.571599e+09
# title_year                   1.965483e+03
# actor_2_facebook_likes       1.867121e+04
# imdb_score                   4.741401e+02
# aspect_ratio                 4.726493e+02
# movie_facebook_likes         4.934943e+04
# dtype: float64

# %% [markdown]
# # MEAN OF PARTICULAR COLUMN (HERE ASPECT RATIO)

# %%
df2=df1['aspect_ratio'].mean()

# %%
df2
# Out:
# 472.64925552347

# %% [markdown]
# # TO LOAD MEDIAN

# %%
df1.median()
# Out:
# num_critic_for_reviews       1.531961e+02
# duration                     1.081301e+02
# director_facebook_likes      5.212318e+02
# actor_3_facebook_likes       7.312425e+02
# actor_1_facebook_likes       5.754195e+03
# gross                        4.135962e+07
# num_voted_users              7.991297e+04
# cast_total_facebook_likes    7.795079e+03
# facenumber_in_poster         1.688815e+00
# num_user_for_reviews         3.677073e+02
# budget                       3.562405e+07
# title_year                   2.003487e+03
# actor_2_facebook_likes       1.499157e+03
# imdb_score                   6.532370e+00
# aspect_ratio                 2.230475e+00
# movie_facebook_likes         6.552198e+03
# dtype: float64

# %% [markdown]
# # MEDIAN OF PARTICULAR COLUMN (HERE IMDB SCORE)

# %%
df2=df1['imdb_score'].median()

# %%
df2
# Out:
# 6.53237017310253

# %% [markdown]
# # TO LOAD MODE

# %%
df1.mode()
# Out:
#    num_critic_for_reviews     duration  director_facebook_likes  \
# 0                2.000000    22.649332                 0.000000
# 1               77.000000    37.000000                11.000000
# 2              123.465521    96.000000                64.000000
# 3              139.000000   106.000000               235.000000
# 4              167.392277   110.260186               807.463648
# 5              224.000000   120.000000              3068.570417
# 6              813.000000   330.000000              3755.000000
# 7             3755.000000  3755.000000             23000.000000
#
#    actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# 0                0.000000                0.000000  1.620000e+02
# 1              194.500000              745.000000  3.755000e+03
# 2              436.000000             1000.000000  8.301882e+06
# 3              691.000000             3755.000000  3.009311e+07
# 4              771.484953             7753.390146  5.262614e+07
# ...

# %% [markdown]
# # TO LOAD STANDARD DEVIATION

# %%
df1.std()
# Out:
# num_critic_for_reviews       1.274323e+03
# duration                     1.289480e+03
# director_facebook_likes      7.870008e+03
# actor_3_facebook_likes       7.836292e+03
# actor_1_facebook_likes       2.242396e+05
# gross                        2.589345e+08
# num_voted_users              5.768938e+05
# cast_total_facebook_likes    2.294342e+05
# facenumber_in_poster         1.325178e+03
# num_user_for_reviews         1.963121e+03
# budget                       4.301420e+09
# title_year                   1.002621e+03
# actor_2_facebook_likes       4.783977e+04
# imdb_score                   1.325671e+03
# aspect_ratio                 1.326280e+03
# movie_facebook_likes         1.213032e+05
# dtype: float64

# %% [markdown]
# # STANDARD DEVIATION OF PARTICULAR COLUMN

# %%
df2=df1['aspect_ratio'].std()

# %%
df2
# Out:
# 1326.2795918719864

# %% [markdown]
# # COUNT UNIQUE OF MAXIMUM COLUMN

# %%
df['imdb_score'].value_counts()
# Out:
# imdb_score
# 6.7    176
# 6.6    162
# 6.5    154
# 6.4    146
# 6.8    143
#       ...
# 2.5      1
# 2.2      1
# 9.2      1
# 2.0      1
# 3.2      1
# Name: count, Length: 74, dtype: int64

# %% [markdown]
# # LOAD SUM

# %%
df1.sum()
# Out:
# num_critic_for_reviews       5.300858e+03
# duration                     4.576910e+03
# director_facebook_likes      3.094103e+04
# actor_3_facebook_likes       3.074245e+04
# actor_1_facebook_likes       6.817743e+05
# gross                        9.887552e+08
# num_voted_users              2.153759e+06
# cast_total_facebook_likes    7.133625e+05
# facenumber_in_poster         3.804419e+03
# num_user_for_reviews         1.028567e+04
# budget                       1.257279e+10
# title_year                   1.572386e+04
# actor_2_facebook_likes       1.493697e+05
# imdb_score                   3.793121e+03
# aspect_ratio                 3.781194e+03
# movie_facebook_likes         3.947954e+05
# dtype: float64

# %% [markdown]
# # SUM OF PARTICULAR COLUMN

# %%
df2=df1['aspect_ratio'].sum()

# %%
df2
# Out:
# 3781.19404418776

# %% [markdown]
# # BOX PLOT
# BOX PLOT OF PACK

# %%
sns.boxplot(x=df['aspect_ratio'])
# Out:
# <Axes: xlabel='aspect_ratio'>

# %% [markdown]
# # BOX PLOT OF MOVIE FACE BOOK LIKES

# %%
sns.boxplot(x=df['movie_facebook_likes'])
# Out:
# <Axes: xlabel='movie_facebook_likes'>

# %% [markdown]
# # BOX PLOT OF DURATION

# %%
sns.boxplot(x=df['duration'])
# Out:
# <Axes: xlabel='duration'>

# %% [markdown]
# # DISTPLOT
# DISTPLOT OF TITLE YEAR

# %%
plt.figure(figsize=(8,4.2),dpi=200)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=10)
sns.distplot(df['title_year'])
plt.show()
# Out:
# C:\Users\thasn\AppData\Local\Temp\ipykernel_5944\3402950512.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['title_year'])

# %% [markdown]
# # HISTOGRAM
# HISTOGRAM OF GROSS

# %%
sns.histplot(df['gross'],palette='hls')
plt.show()
# Out:
# C:\Users\thasn\AppData\Local\Temp\ipykernel_5944\3843694629.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['gross'],palette='hls')

# %% [markdown]
# # HISTOGRAM OF FACE NUMBER IN POSTER

# %%
sns.histplot(df['facenumber_in_poster'],palette='hls')
plt.show()
# Out:
# C:\Users\thasn\AppData\Local\Temp\ipykernel_5944\2843580705.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['facenumber_in_poster'],palette='hls')

# %% [markdown]
# # HISTOGRAM OF BUDGET

# %%
sns.histplot(df['budget'],palette='hls')
plt.show()
# Out:
# C:\Users\thasn\AppData\Local\Temp\ipykernel_5944\1570395670.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(df['budget'],palette='hls')

# %% [markdown]
# # SCATTERPLOT

# %% [markdown]
# SCATTERPLOT TO FIND CORRELATION BETWEEN TWO VARIABLES .HERE SCATTERPLOT IS PLOTED BETWEEN IMDB SCORE AND ASPECT RATIO

# %%
import seaborn as sns
sns.scatterplot(data=df,x='imdb_score',y='aspect_ratio')
# Out:
# <Axes: xlabel='imdb_score', ylabel='aspect_ratio'>

# %% [markdown]
# # SCATTERPLOT BETWEEN GROSS AND BUDGET

# %%
import seaborn as sns
sns.scatterplot(data=df,x='gross',y='budget')
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %% [markdown]
# # SCATTERPLOT BETWEEN TITLE YEAR AND DURATION

# %%
import seaborn as sns
sns.scatterplot(data=df,x='title_year',y='duration')
# Out:
# <Axes: xlabel='title_year', ylabel='duration'>

# %% [markdown]
# # PAIRPLOT

# %%
import seaborn as sns
sns.pairplot(df)

# %% [markdown]
# # LINE PLOT
# LINE PLOT BETWEEN TITLE YEAR AND GROSS

# %%
sns.lineplot(x="title_year", y="gross", data=df)
plt.show()

# %% [markdown]
# # HEATMAPS

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only="country"),cmap='BrBG',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # BARPLOT

# %%
sns.barplot(x="aspect_ratio", y="imdb_score", data=df1)
df1=df.head(100)
df1
# Out:
#    invoice_and_item_number      date  store_number  \
# 0          INV-33179700135  1/4/2021        2576.0
# 1          INV-33196200106  1/4/2021        2649.0
# 2          INV-33184300011  1/4/2021        2539.0
# 3          INV-33184100015  1/4/2021        4024.0
# 4          INV-33174200025  1/4/2021        5385.0
# ..                     ...       ...           ...
# 95         INV-33170400276  1/4/2021        2552.0
# 96         INV-33169200117  1/4/2021        2633.0
# 97         INV-33181500006  1/4/2021        4640.0
# 98         INV-33182600067  1/4/2021        2567.0
# 99         INV-33187300004  1/4/2021        5309.0
#
#                               store_name                address  \
# 0   Hy-Vee Wine and Spirits / Storm Lake         1250 N Lake St
# 1                    Hy-Vee #3 / Dubuque          400 Locust St
# 2         Hy-Vee Food Store / Iowa Falls             640 S. Oak
# 3             Wal-Mart 1546 / Iowa Falls              840 S Oak
# ...

# %% [markdown]
# # CONCLUSION
